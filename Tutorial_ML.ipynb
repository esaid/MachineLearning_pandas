# %% [markdown]
# <a href="https://colab.research.google.com/github/esaid/MachineLearning_pandas/blob/main/Tutorial_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # tutorial ML
# # Machine Learning for Absolute Beginners - Level 2
# # Idan Gabrieli

# %%
# !pip -q install langchain huggingface_hub transformers sentence_transformers

# %%
import os
from google.colab import userdata
APIKEY = userdata.get('HuggingFaceKey')

os.environ['HUGGINGFACEHUB_API_TOKEN'] = APIKEY

# %% [markdown]
# # pandas

# %%
import pandas as pd

# %%
s1 = pd.Series( [11,20,40,13,45,46])

# %%
s1
# Out:
# 0    11
# 1    20
# 2    40
# 3    13
# 4    45
# 5    46
# dtype: int64

# %%
s2 = pd.Series ([11,20,40,13,45,46], index=['a', 'b', 'c', 'd', 'e', 'f'])

# %%
s2
# Out:
# a    11
# b    20
# c    40
# d    13
# e    45
# f    46
# dtype: int64

# %%
s2.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
s2['c']
# Out:
# 40

# %%
s2['c'] = 50
s2['c']
# Out:
# 50

# %%
s3 = pd.Series([1,2,3,4,5])

# %%
# multiply elements
s3 =s3*3

# %%
s3
# Out:
# 0     3
# 1     6
# 2     9
# 3    12
# 4    15
# dtype: int64

# %%
# check element
9 in s3.values
# Out:
# True

# %%
s6 = pd.Series(3 , index = range(5))
s6
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# dtype: int64

# %%
s2
# Out:
# a    11
# b    20
# c    50
# d    13
# e    45
# f    46
# dtype: int64

# %%
# filter
myfilter = s2 > 40

# %%
myfilter
# Out:
# a    False
# b    False
# c     True
# d    False
# e     True
# f     True
# dtype: bool

# %% [markdown]
# # DataFrame  data structure 2D

# %%
import pandas as pd

# %%
dic1 = {'Name' :['David', 'John', 'Martin','Dianna'] , 'Age':[41,19,33,24], 'Weight':[85,76,67,None]}

# %%
df = pd.DataFrame(dic1)

# %%
df
# Out:
#      Name  Age  Weight
# 0   David   41    85.0
# 1    John   19    76.0
# 2  Martin   33    67.0
# 3  Dianna   24     NaN

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Weight'], dtype='object')

# %%
df['Name']
# Out:
# 0     David
# 1      John
# 2    Martin
# 3    Dianna
# Name: Name, dtype: object

# %%
df[['Name', 'Age']]
# Out:
#      Name  Age
# 0   David   41
# 1    John   19
# 2  Martin   33
# 3  Dianna   24

# %%
# 3 fisrt lines
df[:3]
# Out:
#      Name  Age  Weight
# 0   David   41      85
# 1    John   19      76
# 2  Martin   33      67

# %%
# selection colonnes et lignes
df[['Name', 'Age']][:2]
# Out:
#     Name  Age
# 0  David   41
# 1   John   19

# %%
df.Name
# Out:
# 0     David
# 1      John
# 2    Martin
# 3    Dianna
# Name: Name, dtype: object

# %%
# loc iloc for data selection

# %%
df
# Out:
#      Name  Age  Weight
# 0   David   41      85
# 1    John   19      76
# 2  Martin   33      67
# 3  Dianna   24      56

# %%
# df.loc[what rows to filter , what columns to filter]
df.loc[: , 'Name']
# Out:
# 0     David
# 1      John
# 2    Martin
# 3    Dianna
# Name: Name, dtype: object

# %%
df.loc[[0,1], ['Name', 'Age']]
# Out:
#     Name  Age
# 0  David   41
# 1   John   19

# %%
# df.iloc[what rows to filter , what columns to filter]

# %%
df.iloc[1,:]  # present in column structure
# Out:
# Name      John
# Age         19
# Weight      76
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Name      John
# Age         19
# Weight      76
# Name: 1, dtype: object

# %%
df.iloc[1:3, :]
# Out:
#      Name  Age  Weight
# 1    John   19      76
# 2  Martin   33      67

# %%
df
# Out:
#      Name  Age  Weight
# 0   David   41      85
# 1    John   19      76
# 2  Martin   33      67
# 3  Dianna   24      56

# %%
df.iloc[:,[0,2]]  # columns 0 2
# Out:
#      Name  Weight
# 0   David      85
# 1    John      76
# 2  Martin      67
# 3  Dianna      56

# %%
df.iloc[:,0:2] # columns 0 --> 2 exclu
# Out:
#      Name  Age
# 0   David   41
# 1    John   19
# 2  Martin   33
# 3  Dianna   24

# %% [markdown]
# selection columns
#  df.Name

# %%
df.Name
# Out:
# 0     David
# 1      John
# 2    Martin
# 3    Dianna
# Name: Name, dtype: object

# %%
df.iloc[1:3,0:1]   # i by index
# Out:
#      Name
# 1    John
# 2  Martin

# %%
df.loc[[0,1], ['Name','Age']]  # loc by labels
# Out:
#     Name  Age
# 0  David   41
# 1   John   19

# %% [markdown]
# # Loading data into a dataframe

# %%
df['Age'].min()
# Out:
# 19

# %%
df['Age'].max()
# Out:
# 41

# %%
df.describe()
# Out:
#              Age     Weight
# count   4.000000   4.000000
# mean   29.250000  71.000000
# std     9.742518  12.409674
# min    19.000000  56.000000
# 25%    22.750000  64.250000
# 50%    28.500000  71.500000
# 75%    35.000000  78.250000
# max    41.000000  85.000000

# %%
df['Age'].describe()
# Out:
# count     4.000000
# mean     29.250000
# std       9.742518
# min      19.000000
# 25%      22.750000
# 50%      28.500000
# 75%      35.000000
# max      41.000000
# Name: Age, dtype: float64

# %% [markdown]
# Methods Chaining

# %%
df.isnull()
# Out:
#     Name    Age  Weight
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# Weight    1
# dtype: int64

# %%
type(df.isnull().sum())
# Out:
# pandas.core.series.Series

# %% [markdown]
# filtre on ne garde quels donnees ou il n y a pas de NaN

# %%
df.dropna()
# Out:
#      Name  Age  Weight
# 0   David   41    85.0
# 1    John   19    76.0
# 2  Martin   33    67.0

# %% [markdown]
# Sorting and Ranking

# %%
df.sort_values('Age', ascending=False).head(5)
# Out:
#      Name  Age  Weight
# 0   David   41    85.0
# 2  Martin   33    67.0
# 3  Dianna   24     NaN
# 1    John   19    76.0

# %%
df.sort_values('Age', ascending=True).head(5)
# Out:
#      Name  Age  Weight
# 1    John   19    76.0
# 3  Dianna   24     NaN
# 2  Martin   33    67.0
# 0   David   41    85.0

# %%
df.sort_values(['Age','Weight'], ascending=[True, False])[['Age', 'Name','Weight']]
# Out:
#    Age    Name  Weight
# 1   19    John    76.0
# 3   24  Dianna     NaN
# 2   33  Martin    67.0
# 0   41   David    85.0

# %% [markdown]
# Filtering

# %%
df['Age'] == 19
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# Name: Age, dtype: bool

# %%
df[df['Age']>19]
# Out:
#      Name  Age  Weight
# 0   David   41    85.0
# 2  Martin   33    67.0
# 3  Dianna   24     NaN

# %%
df
# Out:
#      Name  Age  Weight
# 0   David   41    85.0
# 1    John   19    76.0
# 2  Martin   33    67.0
# 3  Dianna   24     NaN

# %% [markdown]
# la condition and -->  doit s'ecrire    &

# %%
df[(df['Age']>19) & (df['Weight']>67)]
# Out:
#     Name  Age  Weight
# 0  David   41    85.0

# %%
df
# Out:
#      Name  Age  Weight
# 0   David   41    85.0
# 1    John   19    76.0
# 2  Martin   33    67.0
# 3  Dianna   24     NaN

# %% [markdown]
# la condition or --> doit s'ecrire |

# %%
df[(df['Age']>33) | (df['Weight']>67)]
# Out:
#     Name  Age  Weight
# 0  David   41    85.0
# 1   John   19    76.0

# %% [markdown]
# une autre facon de filtrer

# %%
condition = (df['Age']>33) | (df['Weight']>67)

# %%
df.loc[condition, ['Age' , 'Weight','Name']]
# Out:
#    Age  Weight   Name
# 0   41    85.0  David
# 1   19    76.0   John

# %% [markdown]
# Grouping and aggregation

# %%
dic2 = {'Name' :['David', 'John', 'Martin','Dianna'] , 'Age':[41,19,33,24], 'Weight':[85,76,67,None], 'Sex':['male','male','male','female']}

# %%
df = pd.DataFrame(dic2)

# %%
df
# Out:
#      Name  Age  Weight     Sex
# 0   David   41    85.0    male
# 1    John   19    76.0    male
# 2  Martin   33    67.0    male
# 3  Dianna   24     NaN  female

# %% [markdown]
# les groupes

# %%
df[["Sex", 'Age']].groupby('Sex').mean()
# Out:
#          Age
# Sex
# female  24.0
# male    31.0

# %% [markdown]
# group all columns

# %%
df.groupby('Sex').mean()
# Out:
# <ipython-input-85-fe69c9b95872>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Sex').mean()
#          Age  Weight
# Sex
# female  24.0     NaN
# male    31.0    76.0

# %% [markdown]
# pour la colonne Age on effectue les calculs count, mean, min, max

# %%
df.groupby('Sex')['Age'].agg(['count', 'mean' ,'min', 'max' ])
# Out:
#         count  mean  min  max
# Sex
# female      1  24.0   24   24
# male        3  31.0   19   41

# %% [markdown]
# data cleaning and transformation

# %%
df.head(5)
# Out:
#      Name  Age  Weight     Sex
# 0   David   41    85.0    male
# 1    John   19    76.0    male
# 2  Martin   33    67.0    male
# 3  Dianna   24     NaN  female

# %%
df.shape
# Out:
# (4, 4)

# %% [markdown]
# delete column

# %%
df.drop(['Age'], axis=1 , inplace= True)

# %%
df.shape
# Out:
# (4, 3)

# %%
df
# Out:
#      Name  Weight     Sex
# 0   David    85.0    male
# 1    John    76.0    male
# 2  Martin    67.0    male
# 3  Dianna     NaN  female

# %% [markdown]
# delete rows

# %%
df.drop(range(0,2), axis=0, inplace=True)

# %%
df.shape
# Out:
# (2, 3)

# %%
df
# Out:
#      Name  Weight     Sex
# 2  Martin    67.0    male
# 3  Dianna     NaN  female

# %% [markdown]
# Removing duplicate Rows

# %%
dic3 = {'Name' :['David','David', 'John', 'Martin','Martin','Dianna'] , 'Age':[41,41,19,33,33,24], 'Weight':[85,85,76,67,67,None], 'Sex':['male','male','male','male','male','female']}

# %%
df=pd.DataFrame(dic3)

# %%
df
# Out:
#      Name  Age  Weight     Sex
# 0   David   41    85.0    male
# 1   David   41    85.0    male
# 2    John   19    76.0    male
# 3  Martin   33    67.0    male
# 4  Martin   33    67.0    male
# 5  Dianna   24     NaN  female

# %% [markdown]
# trouver la ligne dupliquee

# %%
df.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 2

# %% [markdown]
# filter : les lignes qui sont dupliquees

# %%
df.loc[df.duplicated(),:]
# Out:
#      Name  Age  Weight   Sex
# 1   David   41    85.0  male
# 4  Martin   33    67.0  male

# %%
df.loc[df.duplicated(keep=False),:]
# Out:
#      Name  Age  Weight   Sex
# 0   David   41    85.0  male
# 1   David   41    85.0  male
# 3  Martin   33    67.0  male
# 4  Martin   33    67.0  male

# %%
df.loc[df.duplicated(keep='last'),:]
# Out:
#      Name  Age  Weight   Sex
# 0   David   41    85.0  male
# 3  Martin   33    67.0  male

# %% [markdown]
# drop duplicate

# %%
df.shape
# Out:
# (6, 4)

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
df.shape
# Out:
# (4, 4)

# %%
df
# Out:
#      Name  Age  Weight     Sex
# 0   David   41    85.0    male
# 2    John   19    76.0    male
# 3  Martin   33    67.0    male
# 5  Dianna   24     NaN  female

# %% [markdown]
# drop duplicate in a specific column

# %%
dic4 = {'Name' :['David','David', 'John', 'Martin','Martin','Dianna'] , 'Age':[41,43,19,33,37,24], 'Weight':[85,89,76,67,69,None], 'Sex':['male','male','male','male','male','female']}

# %%
df = pd.DataFrame(dic4)

# %%
df
# Out:
#      Name  Age  Weight     Sex
# 0   David   41    85.0    male
# 1   David   43    89.0    male
# 2    John   19    76.0    male
# 3  Martin   33    67.0    male
# 4  Martin   37    69.0    male
# 5  Dianna   24     NaN  female

# %%
df.shape
# Out:
# (6, 4)

# %%
df['Name'].duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# Name: Name, dtype: bool

# %%
df['Name'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# supprimer les doublons en selectionnant une colonne specifique ['Name']

# %%
df.drop_duplicates(subset= ['Name'], keep='first', inplace=True)

# %%
df.shape
# Out:
# (4, 4)

# %%
df
# Out:
#      Name  Age  Weight     Sex
# 0   David   41    85.0    male
# 2    John   19    76.0    male
# 3  Martin   33    67.0    male
# 5  Dianna   24     NaN  female

# %% [markdown]
# Renaming column Label

# %%
df.index
# Out:
# Int64Index([0, 2, 3, 5], dtype='int64')

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Weight', 'Sex'], dtype='object')

# %%
df.rename(columns={'Name': 'Full_name'}, inplace=True)

# %%
df
# Out:
#   Full_name  Age  Weight     Sex
# 0     David   41    85.0    male
# 2      John   19    76.0    male
# 3    Martin   33    67.0    male
# 5    Dianna   24     NaN  female

# %% [markdown]
# autre methode

# %%
new_col = ['C1','C2','C3','C4']

# %%
df.columns
# Out:
# Index(['Full_name', 'Age', 'Weight', 'Sex'], dtype='object')

# %%
df.columns = new_col[:]

# %%
df.columns
# Out:
# Index(['C1', 'C2', 'C3', 'C4'], dtype='object')

# %%
df.head()
# Out:
#        C1  C2    C3      C4
# 0   David  41  85.0    male
# 2    John  19  76.0    male
# 3  Martin  33  67.0    male
# 5  Dianna  24   NaN  female

# %% [markdown]
# Dropping Missing Values

# %%
dic5 = {'Name' :['David', 'John', 'Martin','Dianna'] , 'Age':[41,19,33,24], 'Weight':[85,76,67,None]}

# %%
df = pd.DataFrame(dic5)

# %%
df.head()
# Out:
#      Name  Age  Weight
# 0   David   41    85.0
# 1    John   19    76.0
# 2  Martin   33    67.0
# 3  Dianna   24     NaN

# %%
df.isnull().any()
# Out:
# Name      False
# Age       False
# Weight     True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# Weight    1
# dtype: int64

# %%
df.notnull()
# Out:
#    Name   Age  Weight
# 0  True  True    True
# 1  True  True    True
# 2  True  True    True
# 3  True  True   False

# %%
df.shape
# Out:
# (4, 3)

# %%
df.head()
# Out:
#      Name  Age  Weight
# 0   David   41    85.0
# 1    John   19    76.0
# 2  Martin   33    67.0
# 3  Dianna   24     NaN

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (3, 3)

# %%
df.head()
# Out:
#      Name  Age  Weight
# 0   David   41    85.0
# 1    John   19    76.0
# 2  Martin   33    67.0

# %% [markdown]
# Filling in missing value

# %%
df.head()
# Out:
#      Name  Age  Weight
# 0   David   41    85.0
# 1    John   19    76.0
# 2  Martin   33    67.0
# 3  Dianna   24     NaN

# %% [markdown]
# remplacer les valeurs non definies par une valeur moyenne

# %% [markdown]
# inplace = True permet d'effectuer le changement

# %%
df['Weight'].fillna(df['Weight'].mean(), inplace=True)

# %%
df.head()
# Out:
#      Name  Age  Weight
# 0   David   41    85.0
# 1    John   19    76.0
# 2  Martin   33    67.0
# 3  Dianna   24    76.0

# %% [markdown]
# creating dummy variables

# %%
dic2 = {'Name' :['David', 'John', 'Martin','Dianna'] , 'Age':[41,19,33,24], 'Weight':[85,76,67,None], 'Sex':['male','male','male','female']}

# %%
df = pd.DataFrame(dic2)

# %%
df.head()
# Out:
#      Name  Age  Weight     Sex
# 0   David   41    85.0    male
# 1    John   19    76.0    male
# 2  Martin   33    67.0    male
# 3  Dianna   24     NaN  female

# %% [markdown]
# on ajoute une colonne gender_female qui prend comme valeur 0 ou 1 selon la colonne Sex

# %%
df['gender_female']=df['Sex'].map({'male':0, 'female':1})

# %%
df.head()
# Out:
#      Name  Age  Weight     Sex  gender_female
# 0   David   41    85.0    male              0
# 1    John   19    76.0    male              0
# 2  Martin   33    67.0    male              0
# 3  Dianna   24     NaN  female              1

# %% [markdown]
# suppression de la colonne gender_female

# %%
df.drop(['gender_female'], axis=1, inplace=True)

# %%
pd.get_dummies(df,columdf.head()
# Out:
#      Name  Age  Weight     Sex
# 0   David   41    85.0    male
# 1    John   19    76.0    male
# 2  Martin   33    67.0    male
# 3  Dianna   24     NaN  female

# %% [markdown]
# separation de la colonne Sex, Sex_female  Sex_male  ( boolean values )

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
pd.get_dummies(df,columns=['Sex'])
# Out:
#      Name  Age  Weight  Sex_female  Sex_male
# 0   David   41    85.0           0         1
# 1    John   19    76.0           0         1
# 2  Martin   33    67.0           0         1
# 3  Dianna   24     NaN           1         0

# %% [markdown]
# separation de la colonne Sex, Sex_male ( boolean values )

# %%
pd.get_dummies(df,columns=['Sex'], drop_first=True)
# Out:
#      Name  Age  Weight  Sex_male
# 0   David   41    85.0         1
# 1    John   19    76.0         1
# 2  Martin   33    67.0         1
# 3  Dianna   24     NaN         0

# %% [markdown]
# Exporting Pandas Dataframes

# %%
df.to_csv('output1.csv')

# %%
df.to_csv('output1.csv' , index=False)

# %%
df.to_csv('output1.csv' , index=False, header=None)

# %% [markdown]
# # Machine Learning for Absolute Beginners - Level 3
